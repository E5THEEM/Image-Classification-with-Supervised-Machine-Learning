# %%
#Import the required libraries

# %%
import numpy as np #Array operations
import matplotlib.pyplot as plt #show image
import os #join paths
import cv2 #image operations
from tqdm import tqdm #used to show the loading
import random
import pickle
import seaborn as sns
from PIL import Image 
from keras.optimizers import Adam
from tensorflow.keras import datasets, layers, models
from keras.utils import np_utils

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization , GlobalAveragePooling2D, Activation, Flatten, Conv2D,MaxPool2D, MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD
import time

from sklearn.metrics import classification_report,confusion_matrix

# %%
labels = ['Jennie', 'Lisa']
img_size = 50
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                pass
    return data

# %%
#Now we can easily fetch our train and validation data.
train = get_data('BP/train')
val = get_data('BP/test')

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Jennie")
    else:
        l.append("Lisa")
sns.set_style('darkgrid')
sns.countplot(l)

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0]) #column and row 
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'Jennie')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'Lisa')

# %%
#Data Preprocessing

# %%
x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
  x_train.append(feature)
  y_train.append(label)

for feature, label in val:
  x_val.append(feature)
  y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255



x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
#Data augmentation

# %%
#datagen = ImageDataGenerator(
#        featurewise_center=False,  # set input mean to 0 over the dataset
#        samplewise_center=False,  # set each sample mean to 0
#        featurewise_std_normalization=False,  # divide inputs by std of the dataset
#        samplewise_std_normalization=False,  # divide each input by its std
#        zca_whitening=False,  # apply ZCA whitening
#        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
#        zoom_range = 0.2, # Randomly zoom image 
#        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#        horizontal_flip = True,  # randomly flip images
#        vertical_flip=False)  # randomly flip images


#datagen.fit(x_train)

# %%
#CNN model with 3 Convolutional layers

# %%
model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=(img_size,img_size,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 50, 50, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 25, 25, 32)        9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               295040
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 323,938
# Trainable params: 323,938
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(lr=0.000001)
model.compile(optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) , metrics = ['accuracy'])
history = model.fit(x_train,y_train,epochs = 10 , validation_data = (x_val, y_val))
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 76ms/step - loss: 0.6956 - accuracy: 0.4833 - val_loss: 0.6935 - val_accuracy: 0.4900
# Epoch 2/10
# 10/10 [==============================] - 1s 63ms/step - loss: 0.6952 - accuracy: 0.5033 - val_loss: 0.6934 - val_accuracy: 0.4933
# Epoch 3/10
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6925 - accuracy: 0.5200 - val_loss: 0.6934 - val_accuracy: 0.4900
# Epoch 4/10
# 10/10 [==============================] - 1s 63ms/step - loss: 0.6955 - accuracy: 0.4933 - val_loss: 0.6934 - val_accuracy: 0.4933
# Epoch 5/10
# 10/10 [==============================] - 1s 63ms/step - loss: 0.6970 - accuracy: 0.4600 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 6/10
# 10/10 [==============================] - 1s 63ms/step - loss: 0.6986 - accuracy: 0.4533 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 7/10
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6959 - accuracy: 0.4600 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 8/10
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6947 - accuracy: 0.5133 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 9/10
# 10/10 [==============================] - 1s 63ms/step - loss: 0.6962 - accuracy: 0.4700 - val_loss: 0.6932 - val_accuracy: 0.4833
# Epoch 10/10
# 10/10 [==============================] - 1s 63ms/step - loss: 0.6945 - accuracy: 0.5067 - val_loss: 0.6931 - val_accuracy: 0.4800

# %%
#Evaluating the result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#precision and accuracy.

# %%
predictions = model.predict_classes(x_val)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = ['Jennie (Class 0)','Lisa (Class 1)']))
# Out:
#                   precision    recall  f1-score   support
#
# Jennie (Class 0)       0.41      0.09      0.14       150
#   Lisa (Class 1)       0.49      0.87      0.63       150
#
#         accuracy                           0.48       300
#        macro avg       0.45      0.48      0.38       300
#     weighted avg       0.45      0.48      0.38       300

# %%
model.evaluate(x_val, y_val)
# Out:
# 10/10 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.4800
# [0.6931231617927551, 0.47999998927116394]

# %%
#this is to filter out into 12 images of 50x50 
sample = x_train[-13:-1]
sample = np.array(sample)
sample = sample.reshape(-1, img_size, img_size,1)
np.shape(sample)
# Out:
# (36, 50, 50, 1)

# %%
fig = plt.figure()
mm = []
num = 0 
for data in sample:
    num = num+1
    img_data = data
    type(data)
    
    y = fig.add_subplot(3,5,num)
    orig = img_data.reshape(img_size, img_size)
    data = img_data.reshape(-1, img_size,img_size, 1)
    mm.append(model.prediction(data))
    
    if mm[num-1] > 0.49: str_label = 'Jennie'
    else: str_label = 'Lisa'
            
    y.imshow(orig,cmap = 'gray')
    plt.title(str_label)
    y.axes.get_xaxis().set_visible(False)
    y.axes.get_yaxis().set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-167-ae9edeca2ffc> in <module>
#      10     orig = img_data.reshape(img_size, img_size)
#      11     data = img_data.reshape(-1, img_size,img_size, 1)
# ---> 12     mm.append(model.prediction(data))
#      13
#      14     if mm[num-1] > 0.49: str_label = 'Jennie'
#
# AttributeError: 'Sequential' object has no attribute 'prediction'
